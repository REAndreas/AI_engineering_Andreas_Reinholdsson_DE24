# %% [markdown]
# ## Structure gemini outputs with Pydantic

# %%
from google import genai
import pydantic

client = genai.Client()

response= client.models.generate_content(
    model = "gemini-2.5-flash",
    contents = "List a few asian soups recipes, a yummy description and list the ingredients"
)

print(response.text)
# Out:
# Get ready for a delicious journey through Asia with these incredibly flavorful soup recipes! Each one offers a unique taste experience, from comforting and mild to spicy and invigorating.
#
# ---
#
# ### 1. Vietnamese Pho Bo (Beef Noodle Soup)
#
# **A Yummy Description:**
# Imagine a deeply soulful broth, slow-simmered for hours until it's incredibly aromatic, infused with the subtle dance of star anise, cinnamon, ginger, and cardamom. This golden elixir cradles tender, thinly sliced beef (sometimes still blushing pink!), delicate slippery rice noodles, and a vibrant bouquet of fresh herbs like basil, mint, and cilantro. Each spoonful is a comforting hug, a fragrant symphony that awakens the senses, with a perfect balance of savory, sweet, and umami, brightened by a squeeze of lime and a hint of chili. It's truly a bowl of pure, unadulterated comfort and culinary art.
#
# **Key Ingredients:**
# *   **For the Broth:** Beef bones (marrow and knuckle), beef flank steak, onions, ginger, star anise, cinnamon sticks, black cardamom pods, cloves, fish sauce, rock sugar, salt.
# *   **For the Noodles:** Flat rice noodles (fresh or dried).
# *   **For Serving:** Thinly sliced raw beef (e.g., eye of round, sirloin), bean sprouts, fresh basil, fresh mint, cilantro, lime wedges, sliced jalapeños or bird's eye chilies, hoisin sauce, Sriracha.
#
# ---
#
# ### 2. Thai Tom Yum Goong (Hot and Sour Shrimp Soup)
#
# **A Yummy Description:**
# Prepare for an exhilarating explosion of flavors! Tom Yum Goong is Thailand's iconic hot and sour delight, a vibrant, zesty, and profoundly aromatic soup that electrifies your palate. It's a thrilling dance of spicy chili, sour lime, and savory fish sauce, beautifully balanced with the fragrant trinity of lemongrass, galangal, and kaffir lime leaves. Plump, juicy shrimp bob in the fiery broth alongside earthy mushrooms, creating a truly addictive experience that is both refreshing and invigorating. Each spoonful is a tropical wake-up call, leaving you craving more!
#
# **Key Ingredients:**
# *   **For the Broth:** Chicken or shrimp stock (or water), lemongrass stalks, galangal (sliced), kaffir lime leaves (torn), fresh bird's eye chilies (crushed), fish sauce, lime juice.
# *   **Main Ingredients:** Large shrimp (peeled and deveined), straw mushrooms or oyster mushrooms.
# *   **Garnish:** Fresh cilantro leaves.
# *   **Optional:** Nam Prik Pao (Thai roasted chili paste in oil) for added depth and color.
#
# ---
#
# ### 3. Japanese Miso Soup
#
# **A Yummy Description:**
# A gentle, warming embrace in a bowl, Miso Soup is Japan's quintessential comfort food – simple yet profoundly satisfying. It's delicately savory and deeply umami-rich, made from earthy miso paste dissolved in a delicate dashi broth. Soft cubes of silken tofu, slippery ribbons of wakame seaweed, and a sprinkle of fresh green onions float gracefully, offering subtle textures and flavors. It's light, restorative, and grounds you with its pure, wholesome goodness, often served as an essential accompaniment to any Japanese meal.
#
# **Key Ingredients:**
# *   **For the Dashi (Broth Base):** Water, kombu (dried kelp), bonito flakes (katsuobushi). *Alternatively, dashi powder for convenience.*
# *   **Main Ingredients:** Miso paste (white, yellow, or red, depending on preference for mildness/intensity), silken or soft tofu (cubed), dried wakame seaweed.
# *   **Garnish:** Sliced green onions (scallions).
#
# ---
#
# ### 4. Korean Kimchi Jjigae (Kimchi Stew)
#
# **A Yummy Description:**
# Imagine a bubbling cauldron of fiery, tangy comfort! Kimchi Jjigae is Korea's beloved kimchi stew, a deeply savory, robust, and utterly satisfying dish that's both hearty and incredibly addictive. Aged, pungent fermented kimchi takes center stage, its bold flavors harmonizing with tender slices of pork belly (or silky tofu), garlic, and a spicy kick from gochugaru (chili powder) and gochujang (chili paste). Served piping hot, it's rich, complex, and delivers a profound sense of warmth and coziness, especially perfect on a chilly day.
#
# **Key Ingredients:**
# *   **Main Ingredients:** Well-fermented kimchi (the older, the better!), pork belly or pork shoulder (sliced), or firm tofu (cubed).
# *   **Aromatics & Spices:** Onion, garlic (minced), gochugaru (Korean chili powder), gochujang (Korean chili paste), kimchi juice (from the kimchi container).
# *   **Broth Base:** Anchovy stock (or water/vegetable stock), soy sauce, sesame oil.
# *   **Optional Add-ins:** Enoki mushrooms, sliced green onions, fresh chilies (e.g., serrano or jalapeño), a raw egg cracked in just before serving.
#
# ---
#
# Enjoy exploring these wonderful Asian soup traditions!

# %%
response= client.models.generate_content(
    model = "gemini-2.5-flash",
    contents = """List a few asian soups recipes, a yummy description and list the ingredients
        give me fields of
        recipe_name: str
        description: str
        ingredients: list[str]

        not in markdown format

    """
)

response.text
# Out:
# "recipe_name: Tom Yum Goong (Thai Hot and Sour Shrimp Soup)\ndescription: A classic Thai soup bursting with vibrant, aromatic flavors – a perfect balance of spicy, sour, salty, and a hint of sweet. Fragrant lemongrass, galangal, and kaffir lime leaves infuse the broth, creating an exhilarating culinary experience that awakens the senses.\ningredients:\n- Shrimp (prawns), peeled and deveined\n- Mushrooms (e.g., straw mushrooms, oyster mushrooms)\n- Lemongrass stalks, bruised and sliced\n- Galangal, sliced\n- Kaffir lime leaves, torn\n- Fresh bird's eye chilies, bruised or sliced\n- Fish sauce\n- Lime juice\n- Chili paste in soybean oil (Nam Prik Pao, optional)\n- Cilantro (coriander) for garnish\n- Water or chicken/vegetable broth\n\nrecipe_name: Shoyu Ramen (Japanese Soy Sauce Noodle Soup)\ndescription: A comforting and deeply savory Japanese noodle soup featuring a clear, brown broth made with a soy sauce base, often enriched with chicken or pork stock. It's typically topped with tender pork chashu, a soft-boiled egg, and various fresh garnishes for a bowl of pure umami bliss.\ningredients:\n- Ramen noodles (fresh or dried)\n- Chicken or pork stock (or a mix)\n- Soy sauce (shoyu)\n- Mirin\n- Sake (optional, for broth)\n- Ginger, sliced\n- Garlic cloves, smashed\n- Pork belly (for chashu)\n- Soft-boiled eggs (ajitsuke tamago)\n- Scallions (green onions), sliced\n- Nori (dried seaweed)\n- Narutomaki (fish cake, optional)\n- Spinach or bok choy (optional)\n- Sesame oil\n\nrecipe_name: Pho Bo (Vietnamese Beef Noodle Soup)\ndescription: A fragrant and deeply satisfying Vietnamese noodle soup, renowned for its clear, intensely aromatic beef broth simmered for hours with warming spices like star anise, cinnamon, and cloves. Served with slippery rice noodles, tender slices of beef, and a vibrant array of fresh herbs and sprouts, it's a hug in a bowl.\ningredients:\n- Beef bones (marrow bones, knuckle bones)\n- Beef (e.g., brisket, flank, eye of round for slicing)\n- Rice noodles (pho banh pho)\n- Onions\n- Ginger\n- Star anise\n- Cinnamon sticks\n- Cloves\n- Black cardamom pods\n- Fish sauce\n- Rock sugar (or granulated sugar)\n- Salt\n- Fresh herbs: cilantro, basil, mint\n- Bean sprouts\n- Lime wedges\n- Fresh chilies (e.g., bird's eye chilies)\n- Hoisin sauce and sriracha (for serving)\n\nrecipe_name: Laksa (Malaysian/Singaporean Spicy Coconut Noodle Soup)\ndescription: A rich, creamy, and wonderfully spicy coconut curry noodle soup that is a true Southeast Asian comfort food. It boasts a complex flavor profile from a fragrant spice paste (rempah), infused into a luscious coconut milk broth, typically served with thick wheat noodles or rice vermicelli, and an assortment of toppings like shrimp, chicken, and tofu puffs.\ningredients:\n- Coconut milk\n- Chicken or seafood broth\n- Laksa paste (can be homemade or store-bought; typically contains chilies, shallots, garlic, galangal, lemongrass, turmeric, candlenuts, belacan/shrimp paste)\n- Thick wheat noodles or rice vermicelli\n- Shrimp (prawns)\n- Chicken breast or thighs, cooked and shredded\n- Fish cakes or fish balls\n- Tofu puffs (tau pok)\n- Bean sprouts\n- Hard-boiled eggs, halved\n- Cilantro (coriander) for garnish\n- Lime wedges\n- Laksa leaves (Vietnamese coriander/polygonum, optional)\n- Oil for cooking"

# %%
print(response.text)
# Out:
# recipe_name: Tom Yum Goong (Thai Hot and Sour Shrimp Soup)
# description: A classic Thai soup bursting with vibrant, aromatic flavors – a perfect balance of spicy, sour, salty, and a hint of sweet. Fragrant lemongrass, galangal, and kaffir lime leaves infuse the broth, creating an exhilarating culinary experience that awakens the senses.
# ingredients:
# - Shrimp (prawns), peeled and deveined
# - Mushrooms (e.g., straw mushrooms, oyster mushrooms)
# - Lemongrass stalks, bruised and sliced
# - Galangal, sliced
# - Kaffir lime leaves, torn
# - Fresh bird's eye chilies, bruised or sliced
# - Fish sauce
# - Lime juice
# - Chili paste in soybean oil (Nam Prik Pao, optional)
# - Cilantro (coriander) for garnish
# - Water or chicken/vegetable broth
#
# recipe_name: Shoyu Ramen (Japanese Soy Sauce Noodle Soup)
# description: A comforting and deeply savory Japanese noodle soup featuring a clear, brown broth made with a soy sauce base, often enriched with chicken or pork stock. It's typically topped with tender pork chashu, a soft-boiled egg, and various fresh garnishes for a bowl of pure umami bliss.
# ingredients:
# - Ramen noodles (fresh or dried)
# - Chicken or pork stock (or a mix)
# - Soy sauce (shoyu)
# - Mirin
# - Sake (optional, for broth)
# - Ginger, sliced
# - Garlic cloves, smashed
# - Pork belly (for chashu)
# - Soft-boiled eggs (ajitsuke tamago)
# - Scallions (green onions), sliced
# - Nori (dried seaweed)
# - Narutomaki (fish cake, optional)
# - Spinach or bok choy (optional)
# - Sesame oil
#
# recipe_name: Pho Bo (Vietnamese Beef Noodle Soup)
# description: A fragrant and deeply satisfying Vietnamese noodle soup, renowned for its clear, intensely aromatic beef broth simmered for hours with warming spices like star anise, cinnamon, and cloves. Served with slippery rice noodles, tender slices of beef, and a vibrant array of fresh herbs and sprouts, it's a hug in a bowl.
# ingredients:
# - Beef bones (marrow bones, knuckle bones)
# - Beef (e.g., brisket, flank, eye of round for slicing)
# - Rice noodles (pho banh pho)
# - Onions
# - Ginger
# - Star anise
# - Cinnamon sticks
# - Cloves
# - Black cardamom pods
# - Fish sauce
# - Rock sugar (or granulated sugar)
# - Salt
# - Fresh herbs: cilantro, basil, mint
# - Bean sprouts
# - Lime wedges
# - Fresh chilies (e.g., bird's eye chilies)
# - Hoisin sauce and sriracha (for serving)
#
# recipe_name: Laksa (Malaysian/Singaporean Spicy Coconut Noodle Soup)
# description: A rich, creamy, and wonderfully spicy coconut curry noodle soup that is a true Southeast Asian comfort food. It boasts a complex flavor profile from a fragrant spice paste (rempah), infused into a luscious coconut milk broth, typically served with thick wheat noodles or rice vermicelli, and an assortment of toppings like shrimp, chicken, and tofu puffs.
# ingredients:
# - Coconut milk
# - Chicken or seafood broth
# - Laksa paste (can be homemade or store-bought; typically contains chilies, shallots, garlic, galangal, lemongrass, turmeric, candlenuts, belacan/shrimp paste)
# - Thick wheat noodles or rice vermicelli
# - Shrimp (prawns)
# - Chicken breast or thighs, cooked and shredded
# - Fish cakes or fish balls
# - Tofu puffs (tau pok)
# - Bean sprouts
# - Hard-boiled eggs, halved
# - Cilantro (coriander) for garnish
# - Lime wedges
# - Laksa leaves (Vietnamese coriander/polygonum, optional)
# - Oil for cooking

# %%
from pydantic import BaseModel

class Recipe(BaseModel):
    recipe_name: str
    description: str
    ingredients: list[str]

response= client.models.generate_content(
    model = "gemini-2.5-flash",
    contents = "List a few asian soups recipes, a yummy description and list the ingredients",
    config= {"response_mime_type": "application/json", "response_schema": list[Recipe]}
)

print(response.text)
# Out:
# [
#   {
#     "recipe_name": "Tom Yum Goong",
#     "description": "A classic Thai hot and sour soup, bursting with aromatic herbs, spicy chilies, and tangy lime, featuring succulent shrimp and mushrooms in a flavorful broth.",
#     "ingredients": [
#       "Shrimp",
#       "Lemongrass",
#       "Galangal",
#       "Kaffir lime leaves",
#       "Mushrooms",
#       "Fish sauce",
#       "Lime juice",
#       "Chili paste (Nam Prik Pao)",
#       "Fresh chilies",
#       "Cilantro"
#     ]
#   },
#   {
#     "recipe_name": "Miso Soup",
#     "description": "A comforting and traditional Japanese soup, featuring a savory dashi broth infused with umami-rich miso paste, delicate tofu, and slippery wakame seaweed, garnished with fresh scallions.",
#     "ingredients": [
#       "Miso paste",
#       "Dashi broth",
#       "Silken tofu",
#       "Wakame seaweed (dried)",
#       "Scallions"
#     ]
#   },
#   {
#     "recipe_name": "Pho Bo",
#     "description": "A beloved Vietnamese beef noodle soup renowned for its rich, fragrant broth, tender slices of beef, and slippery rice noodles, often garnished with fresh herbs and bean sprouts.",
#     "ingredients": [
#       "Beef bones",
#       "Beef brisket or round steak",
#       "Rice noodles (banh pho)",
#       "Onion",
#       "Ginger",
#       "Star anise",
#       "Cinnamon stick",
#       "Cloves",
#       "Fish sauce",
#       "Bean sprouts",
#       "Basil",
#       "Lime",
#       "Jalapeño"
#     ]
#   }
# ]

# %%
recipes = response.parsed

len(recipes)
# Out:
# 3

# %%
recipes[0].description
# Out:
# 'A classic Thai hot and sour soup, bursting with aromatic herbs, spicy chilies, and tangy lime, featuring succulent shrimp and mushrooms in a flavorful broth.'

# %%
recipes[0].recipe_name
# Out:
# 'Tom Yum Goong'

# %%
recipes[0].ingredients
# Out:
# ['Shrimp',
#  'Lemongrass',
#  'Galangal',
#  'Kaffir lime leaves',
#  'Mushrooms',
#  'Fish sauce',
#  'Lime juice',
#  'Chili paste (Nam Prik Pao)',
#  'Fresh chilies',
#  'Cilantro']

# %% [markdown]
# ## simulate house prices

# %%
from typing import Literal

class Home(BaseModel):
    price: int
    monthly_fee: int
    living_area: float
    number_rooms: int
    type: Literal["apartment", "house"]
    address: str

response = client.models.generate_content(
    model = "gemini-2.5-pro",
    contents= """
    List 50 apartments and houses in Sweden with their monthly fee, price,
    living area, number of rooms, address, type if it is apartment or house. All currencies are in 
    SEK. Data should be simulation of swedish housing.

""",
    config = {"response_mime_type": "application/json", "response_schema": list[Home]}
)

# %%
homes = response.parsed
len(homes)
# Out:
# 50

# %%
homes[0].price, homes[0].address
# Out:
# (5450000, 'Hornsgatan 42, 118 21 Stockholm')

# %%
homes[0].__dict__
# Out:
# {'price': 5450000,
#  'monthly_fee': 3210,
#  'living_area': 58.5,
#  'number_rooms': 2,
#  'type': 'apartment',
#  'address': 'Hornsgatan 42, 118 21 Stockholm'}

# %%
response.text
# Out:
# '[\n  {\n    "price": 5450000,\n    "monthly_fee": 3210,\n    "living_area": 58.5,\n    "number_rooms": 2,\n    "type": "apartment",\n    "address": "Hornsgatan 42, 118 21 Stockholm"\n  },\n  {\n    "price": 7800000,\n    "monthly_fee": 4500,\n    "living_area": 145.0,\n    "number_rooms": 5,\n    "type": "house",\n    "address": "Långa Runtan 15, 239 42 Skanör"\n  },\n  {\n    "price": 4100000,\n    "monthly_fee": 4150,\n    "living_area": 72.0,\n    "number_rooms": 3,\n    "type": "apartment",\n    "address": "Linnégatan 18, 413 04 Göteborg"\n  },\n  {\n    "price": 2150000,\n    "monthly_fee": 2850,\n    "living_area": 41.0,\n    "number_rooms": 1,\n    "type": "apartment",\n    "address": "Sankt Larsgatan 3, 222 21 Lund"\n  },\n  {\n    "price": 12500000,\n    "monthly_fee": 5800,\n    "living_area": 180.0,\n    "number_rooms": 6,\n    "type": "house",\n    "address": "Villavägen 9, 168 55 Bromma"\n  },\n  {\n    "price": 3200000,\n    "monthly_fee": 3800,\n    "living_area": 85.5,\n    "number_rooms": 4,\n    "type": "apartment",\n    "address": "Drottninggatan 7, 211 41 Malmö"\n  },\n  {\n    "price": 1995000,\n    "monthly_fee": 2100,\n    "living_area": 35.0,\n    "number_rooms": 1,\n    "type": "apartment",\n    "address": "Ekonomikumsvägen 10, 752 36 Uppsala"\n  },\n  {\n    "price": 6200000,\n    "monthly_fee": 4100,\n    "living_area": 130.0,\n    "number_rooms": 5,\n    "type": "house",\n    "address": "Björkvägen 22, 436 39 Askim"\n  },\n  {\n    "price": 8900000,\n    "monthly_fee": 5300,\n    "living_area": 95.0,\n    "number_rooms": 4,\n    "type": "apartment",\n    "address": "Karlavägen 88, 115 22 Stockholm"\n  },\n  {\n    "price": 2850000,\n    "monthly_fee": 3300,\n    "living_area": 68.0,\n    "number_rooms": 3,\n    "type": "apartment",\n    "address": "Storgatan 51, 582 23 Linköping"\n  },\n  {\n    "price": 4500000,\n    "monthly_fee": 3900,\n    "living_area": 155.0,\n    "number_rooms": 6,\n    "type": "house",\n    "address": "Eksjövägen 14, 724 63 Västerås"\n  },\n  {\n    "price": 1750000,\n    "monthly_fee": 2950,\n    "living_area": 55.0,\n    "number_rooms": 2,\n    "type": "apartment",\n    "address": "Järnvägsgatan 12, 703 62 Örebro"\n  },\n  {\n    "price": 2100000,\n    "monthly_fee": 3500,\n    "living_area": 78.0,\n    "number_rooms": 3,\n    "type": "apartment",\n    "address": "Kungsgatan 40, 903 25 Umeå"\n  },\n  {\n    "price": 6950000,\n    "monthly_fee": 4800,\n    "living_area": 88.0,\n    "number_rooms": 3,\n    "type": "apartment",\n    "address": "Valhallavägen 110, 114 41 Stockholm"\n  },\n  {\n    "price": 5100000,\n    "monthly_fee": 4200,\n    "living_area": 125.0,\n    "number_rooms": 4,\n    "type": "house",\n    "address": "Parkgatan 7, 217 74 Malmö"\n  },\n  {\n    "price": 3800000,\n    "monthly_fee": 3750,\n    "living_area": 65.0,\n    "number_rooms": 2,\n    "type": "apartment",\n    "address": "Vasagatan 33, 411 24 Göteborg"\n  },\n  {\n    "price": 2900000,\n    "monthly_fee": 3100,\n    "living_area": 62.0,\n    "number_rooms": 2,\n    "type": "apartment",\n    "address": "Klostergatan 19, 753 21 Uppsala"\n  },\n  {\n    "price": 9800000,\n    "monthly_fee": 6200,\n    "living_area": 165.0,\n    "number_rooms": 7,\n    "type": "house",\n    "address": "Strandvägen 5, 182 60 Djursholm"\n  },\n  {\n    "price": 2400000,\n    "monthly_fee": 4010,\n    "living_area": 92.0,\n    "number_rooms": 4,\n    "type": "apartment",\n    "address": "Skolgatan 8, 602 25 Norrköping"\n  },\n  {\n    "price": 11500000,\n    "monthly_fee": 6500,\n    "living_area": 115.0,\n    "number_rooms": 4,\n    "type": "apartment",\n    "address": "Odengatan 78, 113 22 Stockholm"\n  },\n  {\n    "price": 3550000,\n    "monthly_fee": 3400,\n    "living_area": 110.0,\n    "number_rooms": 4,\n    "type": "house",\n    "address": "Tallvägen 3, 582 73 Linköping"\n  },\n  {\n    "price": 2950000,\n    "monthly_fee": 3950,\n    "living_area": 75.0,\n    "number_rooms": 3,\n    "type": "apartment",\n  ...

# %%
import pandas as pd

df = pd.DataFrame(home.__dict__ for home in homes)
df.head()
# Out:
#       price  monthly_fee  living_area  number_rooms       type  \
# 0   5450000         3210         58.5             2  apartment
# 1   7800000         4500        145.0             5      house
# 2   4100000         4150         72.0             3  apartment
# 3   2150000         2850         41.0             1  apartment
# 4  12500000         5800        180.0             6      house
#
#                            address
# 0  Hornsgatan 42, 118 21 Stockholm
# 1   Långa Runtan 15, 239 42 Skanör
# 2   Linnégatan 18, 413 04 Göteborg
# 3   Sankt Larsgatan 3, 222 21 Lund
# 4      Villavägen 9, 168 55 Bromma

# %%
cheap_house = df.query("price < 5_000_000 and type == 'house'")
cheap_house
# Out:
#       price  monthly_fee  living_area  number_rooms   type  \
# 10  4500000         3900        155.0             6  house
# 20  3550000         3400        110.0             4  house
# 26  3300000         3850        135.0             5  house
# 29  4750000         4000        140.0             6  house
# 33  4300000         4600        160.0             6  house
# 38  2700000         3450         95.0             4  house
# 40  3100000         3300        120.0             5  house
#
#                                  address
# 10        Eksjövägen 14, 724 63 Västerås
# 20         Tallvägen 3, 582 73 Linköping
# 26          Solbacksvägen 2, 907 38 Umeå
# 29             Ringvägen 1, 212 15 Malmö
# 33           Äppelvägen 8, 703 58 Örebro
# 38            Skogsvägen 16, 903 39 Umeå
# 40  Ryttmästaregatan 3, 582 19 Linköping

# %%
cheap_house.to_csv("cheap_houses.csv", index=False)
